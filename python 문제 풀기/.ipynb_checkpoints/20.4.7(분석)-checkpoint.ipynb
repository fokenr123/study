# %%
import pandas as pd

data = pd.read_csv('./data/covid_19_clean_complete.csv')
data
# Out:
#                      Province/State          Country/Region        Lat  \
# 0                               NaN             Afghanistan  33.000000
# 1                               NaN                 Albania  41.153300
# 2                               NaN                 Algeria  28.033900
# 3                               NaN                 Andorra  42.506300
# 4                               NaN                  Angola -11.202700
# 5                               NaN     Antigua and Barbuda  17.060800
# 6                               NaN               Argentina -38.416100
# 7                               NaN                 Armenia  40.069100
# 8      Australian Capital Territory               Australia -35.473500
# 9                   New South Wales               Australia -33.868800
# 10               Northern Territory               Australia -12.463400
# 11                       Queensland               Australia -28.016700
# ...

# %%
# 데이터 복사해서 사용하기 
df = data.copy()
df
# Out:
#                      Province/State          Country/Region        Lat  \
# 0                               NaN             Afghanistan  33.000000
# 1                               NaN                 Albania  41.153300
# 2                               NaN                 Algeria  28.033900
# 3                               NaN                 Andorra  42.506300
# 4                               NaN                  Angola -11.202700
# 5                               NaN     Antigua and Barbuda  17.060800
# 6                               NaN               Argentina -38.416100
# 7                               NaN                 Armenia  40.069100
# 8      Australian Capital Territory               Australia -35.473500
# 9                   New South Wales               Australia -33.868800
# 10               Northern Territory               Australia -12.463400
# 11                       Queensland               Australia -28.016700
# ...

# %%
# 중복된 나라 찾기 
import pandas as pd 
Country=data.iloc[:, 1]
df = Country.value_counts()
df.index[1]

for i in range(len(df)):
    a = df[i]
    if a > 1:
        print(df.index[i])
# Out:
# China
# Canada
# France
# United Kingdom
# Australia
# Netherlands
# Denmark
# Mozambique
# Israel
# Malta
# Holy See
# Uruguay
# Cuba
# El Salvador
# Central African Republic
# Sweden
# Belize
# Burundi
# Eritrea
# Singapore
# Switzerland
# Guyana
# MS Zaandam
# Niger
# Dominican Republic
# Ghana
# Sri Lanka
# Gabon
# Guinea
# Libya
# Panama
# Moldova
# Maldives
# Haiti
# Italy
# Iran
# Romania
# Colombia
# Vietnam
# Bahamas
# Namibia
# Cote d'Ivoire
# Kyrgyzstan
# Andorra
# San Marino
# Guatemala
# Cabo Verde
# Saudi Arabia
# Jamaica
# Saint Kitts and Nevis
# Armenia
# West Bank and Gaza
# Cyprus
# Burkina Faso
# Algeria
# Equatorial Guinea
# Zimbabwe
# Russia
# Argentina
# Rwanda
# Greece
# Sudan
# Nepal
# Venezuela
# Azerbaijan
# Mauritania
# Egypt
# United Arab Emirates
# Portugal
# Hungary
# Kosovo
# Bolivia
# Iceland
# Benin
# Guinea-Bissau
# Albania
# Sierra Leone
# Ireland
# Belgium
# Jordan
# Antigua and Barbuda
# Cameroon
# Qatar
# Czechia
# Madagascar
# Chad
# Kenya
# ...

# %%
df1 = df.drop(['Province/State'] , axis = 1)
df1
# Out:
#                Country/Region        Lat        Long     Date  Confirmed  \
# 0                 Afghanistan  33.000000   65.000000  1/22/20          0
# 1                     Albania  41.153300   20.168300  1/22/20          0
# 2                     Algeria  28.033900    1.659600  1/22/20          0
# 3                     Andorra  42.506300    1.521800  1/22/20          0
# 4                      Angola -11.202700   17.873900  1/22/20          0
# 5         Antigua and Barbuda  17.060800  -61.796400  1/22/20          0
# 6                   Argentina -38.416100  -63.616700  1/22/20          0
# 7                     Armenia  40.069100   45.038200  1/22/20          0
# 8                   Australia -35.473500  149.012400  1/22/20          0
# 9                   Australia -33.868800  151.209300  1/22/20          0
# 10                  Australia -12.463400  130.845600  1/22/20          0
# 11                  Australia -28.016700  153.400000  1/22/20          0
# ...

# %%
# 위도 경도 빼기
df2 = df1.drop(['Lat', 'Long'] , axis = 1)
df2
# Out:
#                Country/Region     Date  Confirmed  Deaths  Recovered
# 0                 Afghanistan  1/22/20          0       0          0
# 1                     Albania  1/22/20          0       0          0
# 2                     Algeria  1/22/20          0       0          0
# 3                     Andorra  1/22/20          0       0          0
# 4                      Angola  1/22/20          0       0          0
# 5         Antigua and Barbuda  1/22/20          0       0          0
# 6                   Argentina  1/22/20          0       0          0
# 7                     Armenia  1/22/20          0       0          0
# 8                   Australia  1/22/20          0       0          0
# 9                   Australia  1/22/20          0       0          0
# 10                  Australia  1/22/20          0       0          0
# 11                  Australia  1/22/20          0       0          0
# 12                  Australia  1/22/20          0       0          0
# ...

# %%
Confirmed = df2.groupby(['Confirmed']['dataf'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-f6b0d027d860> in <module>
# ----> 1 Confirmed = df2.groupby(['Confirmed']['data'])
#
# TypeError: list indices must be integers or slices, not str
